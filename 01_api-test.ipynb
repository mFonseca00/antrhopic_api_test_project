# %%
#Install dependencies
# %pip install anthropic python-dotenv

# %%
#Load env variables
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
#Create an API client
from anthropic import Anthropic
import os

client = Anthropic()
model = os.environ["ANTHROPIC_MODEL"]
print(model)
# Out:
# anthropic.claude-4-5-haiku

# %%
#Make a request
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "O que é pestanejar?"
        }
    ]
)

# %%
message.content[0].text
# Out:
# '# Pestanejar\n\n**Pestanejar** significa **piscar os olhos repetidamente** ou fazer movimentos rápidos e involuntários com as pálpebras.\n\n## Exemplos de uso:\n\n- "Ela começou a pestanejar quando ficou nervosa"\n- "O pó entrou em meu olho e não parei de pestanejar"\n- "Ele piscava e pestaneja constantemente durante a apresentação"\n\n## Relacionado:\n\n- **Piscar** - fechar e abrir os olhos rapidamente (geralmente uma vez)\n- **Piscadela** - um piscar intencional, frequentemente com conotação de cumplicidade ou flerte\n\nÉ um verbo comum em português para descrever esse movimento involuntário ou repetitivo das pálpebras.'
