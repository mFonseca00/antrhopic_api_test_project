# %%
# %pip install anthropic python-dotenv

# %%
#Load env variables
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
#Create an API client
from anthropic import Anthropic
import os

client = Anthropic()
model = os.environ["ANTHROPIC_MODEL"]
print(model)
# Out:
# anthropic.claude-4-5-haiku

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    if system:
        params["system"] = system
    if stop_sequences:
        params["stop_sequences"] = stop_sequences
    
    response = client.messages.create(**params)
    return response.content[0].text

# %%
import json

def generate_dataset():
  prompt = """
    Generate an evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects, each representing task that requires Python, JSON, or a Regex to complete.

    Example output:
    ```json
    [
      {
        "task": "Description of task",
      },
      ...additional
    ]
    ```

    * Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a single regex
    * Focus on tasks that do not require writing much code

    Please generate 3 objects.
    """

  messages = []
  add_user_message(messages, prompt)
  add_assistant_message(messages, "```json")
  text = chat(messages, stop_sequences=["```"])
  return json.loads(text)

# %%
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []
    
    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)
    
    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 URI Parser\n\nHere's a Python function that parses S3 URIs:\n\n```python\ndef parse_s3_uri(uri):\n    \"\"\"\n    Parse an AWS S3 bucket URI and return bucket name and key.\n    \n    Args:\n        uri (str): S3 URI in the format 's3://bucket-name/path/to/file'\n    \n    Returns:\n        dict: Dictionary with 'bucket' and 'key' keys\n        \n    Raises:\n        ValueError: If the URI format is invalid\n    \n    Example:\n        >>> parse_s3_uri('s3://my-bucket/path/to/file.txt')\n        {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n    \"\"\"\n    if not uri:\n        raise ValueError(\"URI cannot be empty\")\n    \n    if not uri.startswith('s3://'):\n        raise ValueError(\"URI must start with 's3://'\")\n    \n    # Remove the 's3://' prefix\n    uri_without_prefix = uri[5:]\n    \n    # Split on the first '/' to separate bucket from key\n    parts = uri_without_prefix.split('/', 1)\n    \n    bucket = parts[0]\n    key = parts[1] if len(parts) > 1 else ''\n    \n    if not bucket:\n        raise ValueError(\"Bucket name cannot be empty\")\n    \n    return {\n        'bucket': bucket,\n        'key': key\n    }\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Basic usage\n    result = parse_s3_uri('s3://my-bucket/path/to/file.txt')\n    print(result)\n    # Output: {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n    \n    # Bucket only (no key)\n    result = parse_s3_uri('s3://my-bucket/')\n    print(result)\n    # Output: {'bucket': 'my-bucket', 'key': ''}\n    \n    # Bucket only (no trailing slash)\n    result = parse_s3_uri('s3://my-bucket')\n    print(result)\n    # Output: {'bucket': 'my-bucket', 'key': ''}\n    \n    # Complex path\n    result = parse_s3_uri('s3://data-bucket/2023/logs/app.log')\n    print(result)\n    # Output: {'bucket': 'data-bucket', 'key': '2023/logs/app.log'}\n    \n    # Error handling\n    try:\n        parse_s3_uri('http://my-bucket/file.txt')\n    except ValueError as e:\n        print(f\"Error: {e}\")\n        # Output: Error: URI must start with 's3://'\n```\n\n## Alternative: Using urllib.parse\n\nHere's a more robust version using Python's built-in `urllib.parse`:\n\n```python\nfrom urllib.parse import urlparse\n\ndef parse_s3_uri(uri):\n    \"\"\"\n    Parse an AWS S3 bucket URI using urlparse.\n    \n    Args:\n        uri (str): S3 URI in the format 's3://bucket-name/path/to/file'\n    \n    Returns:\n        dict: Dictionary with 'bucket' and 'key' keys\n    \"\"\"\n    if not uri:\n        raise ValueError(\"URI cannot be empty\")\n    \n    parsed = urlparse(uri)\n    \n    if parsed.scheme != 's3':\n        raise ValueError(\"URI must start with 's3://'\")\n    \n    bucket = parsed.netloc\n    key = parsed.path.lstrip('/')  # Remove leading slash\n    \n    if not bucket:\n        raise ValueError(\"Bucket name cannot be empty\")\n    \n    return {\n        'bucket': bucket,\n        'key': key\n    }\n\n\n# Test cases\nif __name__ == \"__main__\":\n    print(parse_s3_uri('s3://my-bucket/path/to/file.txt'))\n    # Output: {'bucket': 'my-bucket', 'key': 'path/to/file.",
#     "test_case": {
#       "task": "Write a Python function that parses an AWS S3 bucket URI (e.g., 's3://my-bucket/path/to/file.txt') and returns a dictionary with keys 'bucket' and 'key'"
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS IAM Read-Only S3 Bucket Policy\n\nHere's a JSON object representing an AWS IAM policy for read-only access to a specific S3 bucket:\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListBucketContents\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": [\n        \"arn:aws:s3:::my-data-bucket\",\n        \"arn:aws:s3:::my-data-bucket/*\"\n      ]\n    }\n  ]\n}\n```\n\n## Breakdown:\n\n| Component | Description |\n|-----------|-------------|\n| **Version** | `2012-10-17` - The standard AWS policy language version |\n| **Effect** | `Allow` - Permits the specified actions |\n| **Actions** | `s3:ListBucket` - List bucket contents<br>`s3:GetObject` - Read/download objects |\n| **Resources** | `arn:aws:s3:::my-data-bucket` - Bucket itself<br>`arn:aws:s3:::my-data-bucket/*` - All objects in bucket |\n| **Sid** | Optional identifier for the statement |\n\n## Usage:\n\nThis policy can be:\n- Attached to an IAM user, group, or role\n- Used as an inline policy\n- Configured as a bucket policy (with principal added)\n\n## Related Actions (Not Included):\nTo maintain read-only access, excluded actions like `s3:PutObject`, `s3:DeleteObject`, etc.",
#     "test_case": {
#       "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to a specific S3 bucket named 'my-data-bucket'"
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS EC2 Instance ID Regex Pattern\n\nHere's the regex pattern that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[a-z0-9]{17}$\n```\n\n## Breakdown:\n\n| Component | Description |\n|-----------|-------------|\n| `^` | Start of string |\n| `i-` | Literal \"i-\" prefix |\n| `[a-z0-9]` | Character class matching lowercase letters (a-z) or digits (0-9) |\n| `{17}` | Exactly 17 characters from the character class |\n| `$` | End of string |\n\n## Examples:\n\n```javascript\n// Valid matches\ni-0a1b2c3d4e5f6g7h8\ni-1234567890abcdef0\n\n// Invalid (won't match)\nI-0a1b2c3d4e5f6g7h8    // uppercase I\ni-0a1b2c3d4e5f6g7      // only 16 characters\ni-0a1b2c3d4e5f6g7h8i   // 18 characters\ni_0a1b2c3d4e5f6g7h8    // underscore instead of hyphen\n```\n\n## Usage Examples:\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[a-z0-9]{17}$/;\nconsole.log(pattern.test('i-0a1b2c3d4e5f6g7h8')); // true\n```\n\n**Python:**\n```python\nimport re\npattern = r'^i-[a-z0-9]{17}$'\nre.match(pattern, 'i-0a1b2c3d4e5f6g7h8')  # Match object (True)\n```",
#     "test_case": {
#       "task": "Write a regex pattern that matches valid AWS EC2 instance IDs (format: i- followed by 17 alphanumeric characters)"
#     },
#     "score": 10
#   }
# ]
